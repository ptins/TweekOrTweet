# %%
# keys/tokens/secrets
consumer_key = '6FTGkkHr6qIv6drlW531oLWZH'
consumer_secret = '6e3lSCAwy2DZQawH6N7ttTyiHbFUMuJs9GYHTHfKd2mydS2xZB'
access_token = '1959972582-DfvT6r2zpKLs4BSRd4KSYfxUycGvpinzXMsGcRm'
access_token_secret = 'pCzDlv6AhzK5L8cTUMIVAmRjdVxkOWYzyE1qPUjn2Xch6'

# %%
# tweepy setup 
import tweepy

# %%
# oauth setup
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# jfallon = api.user_timeline('jimmyfallon', count=1000)

# %%
for tweet in jfallon:
    print('Tweet: {}\nFavorite Count: {}\nRetweet Count: {}\nUser: {}\n'
          .format(tweet.text, tweet.favorite_count, tweet.retweet_count, tweet.entities))
# Out:
# Tweet: Around 11-ish I’m on with @RealSway on @Shade45.
# Favorite Count: 770
# Retweet Count: 67
# User: {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RealSway', 'name': 'Sway Calloway', 'id': 45203497, 'id_str': '45203497', 'indices': [26, 35]}, {'screen_name': 'Shade45', 'name': 'Shade45', 'id': 22829495, 'id_str': '22829495', 'indices': [39, 47]}], 'urls': []}
#
# Tweet: Tonight on #FallonFive: @desusandmero stop by to give their take on the Winter #Olympics!
# Favorite Count: 1137
# Retweet Count: 141
# User: {'hashtags': [{'text': 'FallonFive', 'indices': [11, 22]}, {'text': 'Olympics', 'indices': [79, 88]}], 'symbols': [], 'user_mentions': [{'screen_name': 'desusandmero', 'name': 'DESUS & MERO', 'id': 780454154959523840, 'id_str': '780454154959523840', 'indices': [24, 37]}], 'urls': []}
#
# Tweet: I will be on @MorningMashUp around 10:45 this morning. Stay in your cars or wherever you listen to SiriusXM. Fun.
# Favorite Count: 1174
# Retweet Count: 94
# ...

# %%
# jfallon_user = api.get_user('jimmyfallon')

# %%
jfallon_user
# Out:
# User(_api=<tweepy.api.API object at 0x10f29bc18>, _json={'id': 15485441, 'id_str': '15485441', 'name': 'jimmy fallon', 'screen_name': 'jimmyfallon', 'location': 'New York, New York', 'profile_location': None, 'description': 'astrophysicist', 'url': 'http://t.co/fgp5RYqr3T', 'entities': {'url': {'urls': [{'url': 'http://t.co/fgp5RYqr3T', 'expanded_url': 'http://www.tonightshow.com', 'display_url': 'tonightshow.com', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 50486064, 'friends_count': 7800, 'listed_count': 68034, 'created_at': 'Fri Jul 18 19:46:50 +0000 2008', 'favourites_count': 69, 'utc_offset': -18000, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': True, 'verified': True, 'statuses_count': 10474, 'lang': 'en', 'status': {'created_at': 'Tue Feb 20 14:55:52 +0000 2018', 'id': 965963219385937920, 'id_str': '965963219385937920', 'text': 'Around 11-ish I’m on with @RealSway on @Shade45.', 'truncated': False, 'entities': {'hasht
# ...

# %%
print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x10f29bc18>, _json={'created_at': 'Fri Dec 01 13:26:33 +0000 2017', 'id': 936587324049281024, 'id_str': '936587324049281024', 'text': 'Your funniest #DecorationDisaster tweets! https://t.co/0s88ssjFYQ #FallonTonight', 'truncated': False, 'entities': {'hashtags': [{'text': 'DecorationDisaster', 'indices': [14, 33]}, {'text': 'FallonTonight', 'indices': [66, 80]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/0s88ssjFYQ', 'expanded_url': 'https://www.youtube.com/watch?v=9k5y_aO-8Jo', 'display_url': 'youtube.com/watch?v=9k5y_a…', 'indices': [42, 65]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 15485441, 'id_str': '15485441', 'name': 'jimmy fallon', 'screen_name': 'jimmyfallon', 'location': 'New York, New York', 'des
# ...
